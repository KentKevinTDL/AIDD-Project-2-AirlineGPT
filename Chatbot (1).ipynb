# %% [markdown]
# # **Chat Bot - AirlineGPT**

# %% [markdown]
# **Rasa file**
#
# Introducing Rasa, the backbone of our innovative chatbot system. Rasa is an open-source conversational AI platform that empowers our chatbot with natural language understanding and interactive capabilities. Seamlessly integrated into our project, Rasa allows our chatbot to comprehend and respond to user queries, providing a personalized and engaging experience. With its robust features and machine learning capabilities, Rasa enables us to deliver a cutting-edge chatbot that not only simplifies flight bookings but also enhances user interactions. Together with Rasa, our chatbot is at the forefront of transforming how users engage with our flight booking system, making it intuitive, dynamic, and user-centric.

# %%
# !pip install rasa==3.4.5 #installing a particular version of rasa as colab is only compatitable with this verison
# Out:
# Collecting rasa==3.4.5
#   Downloading rasa-3.4.5-py3-none-any.whl.metadata (25 kB)
# Collecting CacheControl<0.13.0,>=0.12.9 (from rasa==3.4.5)
#   Downloading CacheControl-0.12.14-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4.5) (2.10.1)
# Collecting SQLAlchemy<1.5.0,>=1.4.0 (from rasa==3.4.5)
#   Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting absl-py<1.4,>=0.9 (from rasa==3.4.5)
#   Downloading absl_py-1.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting aio-pika<9.0.0,>=6.7.1 (from rasa==3.4.5)
#   Downloading aio_pika-8.3.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting aiogram<2.24 (from rasa==3.4.5)
#   Downloading aiogram-2.23.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting aiohttp!=3.7.4.post0,<3.9,>=3.6 (from rasa==3.4.5)
#   Downloading aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting apscheduler<3.10,>=3.6 (from rasa==3.4.5)
#   Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting attrs<22.2,>=19.3 (from rasa==3.4.5)
#   Downloading attrs-22.1.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting boto3<2.0,>=1.12 (from rasa==3.4.5)
#   Downloading boto3-1.35.93-py3-none-any.whl.metadata (6.7 kB)
# Collecting cloudpickle<2.3,>=1.2 (from rasa==3.4.5)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting colorclass<2.3,>=2.2 (from rasa==3.4.5)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting coloredlogs<16,>=10 (from rasa==3.4.5)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting colorhash<1.3.0,>=1.0.2 (from rasa==3.4.5)
#   Downloading colorhash-1.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting confluent-kafka<2.0.0,>=1.9.2 (from rasa==3.4.5)
#   Downloading confluent_kafka-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting dask==2022.10.2 (from rasa==3.4.5)
#   Downloading dask-2022.10.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting fbmessenger<6.1.0,>=6.0.0 (from rasa==3.4.5)
#   Downloading fbmessenger-6.0.0-py2.py3-none-any.whl.metadata (869 bytes)
# Requirement already satisfied: google-auth<3 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (2.27.0)
# Collecting joblib<1.3.0,>=0.15.1 (from rasa==3.4.5)
#   Downloading joblib-1.2.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting jsonpickle<2.3,>=1.3 (from rasa==3.4.5)
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting jsonschema<4.17,>=3.2 (from rasa==3.4.5)
#   Downloading jsonschema-4.16.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting matplotlib<3.6,>=3.1 (from rasa==3.4.5)
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting mattermostwrapper<2.3,>=2.2 (from rasa==3.4.5)
#   Downloading mattermostwrapper-2.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting networkx<2.7,>=2.4 (from rasa==3.4.5)
#   Downloading networkx-2.6.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting numpy<1.24.0,>=1.19.2 (from rasa==3.4.5)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting packaging<21.0,>=20.0 (from rasa==3.4.5)
#   Downloading packaging-20.9-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (1.5.0)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa==3.4.5)
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf<3.20,>=3.9.2 (from rasa==3.4.5)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (787 bytes)
# Collecting psycopg2-binary<2.10.0,>=2.8.2 (from rasa==3.4.5)
#   Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting pydantic<1.10.3 (from rasa==3.4.5)
#   Downloading pydantic-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 5.8 MB/s eta 0:00:00
# Collecting pydot<1.5,>=1.4 (from rasa==3.4.5)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting pykwalify<1.9,>=1.7 (from rasa==3.4.5)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting pymongo<3.11,>=3.8 (from pymongo[srv,tls]<3.11,>=3.8->rasa==3.4.5)
#   Downloading pymongo-3.10.1.tar.gz (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.9/715.9 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (2.8.2)
# Collecting python-engineio!=5.0.0,<6,>=4 (from rasa==3.4.5)
#   Downloading python_engineio-4.11.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-socketio<6,>=4.4 (from rasa==3.4.5)
#   Downloading python_socketio-5.12.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz<2023.0,>=2019.1 (from rasa==3.4.5)
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting questionary<1.11.0,>=1.5.1 (from rasa==3.4.5)
#   Downloading questionary-1.10.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting randomname<0.2.0,>=0.1.5 (from rasa==3.4.5)
#   Downloading randomname-0.1.5.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rasa-sdk<3.5.0,>=3.4.1 (from rasa==3.4.5)
#   Downloading rasa_sdk-3.4.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting redis<5.0,>=3.4 (from rasa==3.4.5)
#   Downloading redis-4.6.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting regex<2022.11,>=2020.6 (from rasa==3.4.5)
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (2.32.3)
# Collecting rocketchat_API<1.29.0,>=0.6.31 (from rasa==3.4.5)
#   Downloading rocketchat_API-1.28.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting ruamel.yaml<0.18.0,>=0.16.5 (from rasa==3.4.5)
#   Downloading ruamel.yaml-0.17.40-py3-none-any.whl.metadata (19 kB)
# Collecting sanic<21.13,>=21.12 (from rasa==3.4.5)
#   Downloading sanic-21.12.2-py3-none-any.whl.metadata (11 kB)
# Collecting sanic-cors<2.1.0,>=2.0.0 (from rasa==3.4.5)
#   Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting sanic-jwt<2.0.0,>=1.6.0 (from rasa==3.4.5)
#   Downloading sanic_jwt-1.8.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sanic-routing<0.8.0,>=0.7.2 (from rasa==3.4.5)
#   Downloading sanic_routing-0.7.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting scikit-learn<1.2,>=0.22 (from rasa==3.4.5)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting scipy<1.9.0,>=1.4.1 (from rasa==3.4.5)
#   Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting sentry-sdk<1.12.0,>=0.17.0 (from rasa==3.4.5)
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (75.1.0)
# Collecting sklearn-crfsuite<0.4,>=0.3 (from rasa==3.4.5)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting slack-sdk<4.0.0,>=3.19.2 (from rasa==3.4.5)
#   Downloading slack_sdk-3.34.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting tarsafe<0.0.4,>=0.0.3 (from rasa==3.4.5)
#   Downloading tarsafe-0.0.3-py3-none-any.whl.metadata (861 bytes)
# Collecting tensorflow<2.9.0,>=2.8.4 (from rasa==3.4.5)
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl.metadata (2.9 kB)
# Collecting tensorflow-addons<0.18.0,>=0.17.0 (from rasa==3.4.5)
#   Downloading tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tensorflow-text<2.9.0,>=2.8.0 (from rasa==3.4.5)
#   Downloading tensorflow_text-2.8.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.1 kB)
# Collecting tensorflow_hub<0.13.0,>=0.12.0 (from rasa==3.4.5)
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting terminaltables<3.2.0,>=3.1.0 (from rasa==3.4.5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm<5.0,>=4.31 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (4.67.1)
# Collecting twilio<7.15,>=6.26 (from rasa==3.4.5)
#   Downloading twilio-7.14.2-py2.py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4.5) (4.12.2)
# Collecting typing-utils<0.2.0,>=0.1.0 (from rasa==3.4.5)
#   Downloading typing_utils-0.1.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting ujson<6.0,>=1.35 (from rasa==3.4.5)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting webexteamssdk<1.7.0,>=1.1.1 (from rasa==3.4.5)
#   Downloading webexteamssdk-1.6.1-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4.5) (8.1.7)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4.5) (2024.10.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4.5) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4.5) (6.0.2)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4.5) (0.12.1)
# Collecting aiormq~=6.6.3 (from aio-pika<9.0.0,>=6.7.1->rasa==3.4.5)
#   Downloading aiormq-6.6.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: yarl in /usr/local/lib/python3.10/dist-packages (from aio-pika<9.0.0,>=6.7.1->rasa==3.4.5) (1.18.3)
# Collecting Babel<2.10.0,>=2.9.1 (from aiogram<2.24->rasa==3.4.5)
#   Downloading Babel-2.9.1-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from aiogram<2.24->rasa==3.4.5) (2024.12.14)
# Collecting magic-filter>=1.0.9 (from aiogram<2.24->rasa==3.4.5)
#   Downloading magic_filter-1.0.12-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5) (3.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5) (6.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5) (1.3.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa==3.4.5) (1.17.0)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa==3.4.5) (5.2)
# Collecting botocore<1.36.0,>=1.35.93 (from boto3<2.0,>=1.12->rasa==3.4.5)
#   Downloading botocore-1.35.93-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.12->rasa==3.4.5)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0,>=1.12->rasa==3.4.5)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from CacheControl<0.13.0,>=0.12.9->rasa==3.4.5) (1.1.0)
# Collecting humanfriendly>=9.1 (from coloredlogs<16,>=10->rasa==3.4.5)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4.5) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4.5) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4.5) (4.9)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.17,>=3.2->rasa==3.4.5)
#   Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4.5) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4.5) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4.5) (11.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4.5) (3.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa==3.4.5) (0.2.13)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4.5) (43.0.3)
# Collecting docopt>=0.6.2 (from pykwalify<1.9,>=1.7->rasa==3.4.5)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dnspython<2.0.0,>=1.16.0 (from pymongo[srv,tls]<3.11,>=3.8->rasa==3.4.5)
#   Downloading dnspython-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting simple-websocket>=0.10.0 (from python-engineio!=5.0.0,<6,>=4->rasa==3.4.5)
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting bidict>=0.21.0 (from python-socketio<6,>=4.4->rasa==3.4.5)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting fire (from randomname<0.2.0,>=0.1.5->rasa==3.4.5)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa==3.4.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa==3.4.5) (2.2.3)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml<0.18.0,>=0.16.5->rasa==3.4.5)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting httptools>=0.0.10 (from sanic<21.13,>=21.12->rasa==3.4.5)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting aiofiles>=0.6.0 (from sanic<21.13,>=21.12->rasa==3.4.5)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.10/dist-packages (from sanic<21.13,>=21.12->rasa==3.4.5) (14.1)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4.5)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (4.2 kB)
# Collecting uvloop>=0.5.3 (from sanic<21.13,>=21.12->rasa==3.4.5)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2,>=0.22->rasa==3.4.5) (3.5.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite<0.4,>=0.3->rasa==3.4.5)
#   Downloading python_crfsuite-0.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa==3.4.5) (0.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa==3.4.5) (3.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.12.1)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (1.17.0)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (1.68.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons<0.18.0,>=0.17.0->rasa==3.4.5) (4.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa==3.4.5) (1.0.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa==3.4.5) (1.0.0)
# Collecting pamqp==3.2.1 (from aiormq~=6.6.3->aio-pika<9.0.0,>=6.7.1->rasa==3.4.5)
#   Downloading pamqp-3.2.1-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (0.45.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4.5) (1.17.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask==2022.10.2->rasa==3.4.5) (1.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa==3.4.5) (0.6.1)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa==3.4.5)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.7)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.1.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl->aio-pika<9.0.0,>=6.7.1->rasa==3.4.5) (0.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4.5) (2.22)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa==3.4.5) (0.14.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4.5) (3.2.2)
# Downloading rasa-3.4.5-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 33.8 MB/s eta 0:00:00
# Downloading dask-2022.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.7 MB/s eta 0:00:00
# Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 8.5 MB/s eta 0:00:00
# Downloading aio_pika-8.3.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.1 MB/s eta 0:00:00
# Downloading aiogram-2.23.1-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 12.9 MB/s eta 0:00:00
# Downloading aiohttp-3.8.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.3 MB/s eta 0:00:00
# Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.6 MB/s eta 0:00:00
# Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.5 MB/s eta 0:00:00
# Downloading boto3-1.35.93-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.5 MB/s eta 0:00:00
# Downloading CacheControl-0.12.14-py2.py3-none-any.whl (21 kB)
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.5 MB/s eta 0:00:00
# Downloading colorhash-1.2.1-py3-none-any.whl (5.7 kB)
# Downloading confluent_kafka-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.2 MB/s eta 0:00:00
# Downloading fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 16.3 MB/s eta 0:00:00
# Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Downloading jsonschema-4.16.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 5.7 MB/s eta 0:00:00
# Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 85.0 MB/s eta 0:00:00
# Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.0 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 72.2 MB/s eta 0:00:00
# Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.2 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 23.7 MB/s eta 0:00:00
# Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.1 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 67.5 MB/s eta 0:00:00
# Downloading pydantic-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 77.6 MB/s eta 0:00:00
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Downloading python_engineio-4.11.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.7 MB/s eta 0:00:00
# Downloading python_socketio-5.12.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.7 MB/s eta 0:00:00
# Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 30.7 MB/s eta 0:00:00
# Downloading questionary-1.10.0-py3-none-any.whl (31 kB)
# Downloading rasa_sdk-3.4.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.8 MB/s eta 0:00:00
# Downloading redis-4.6.0-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.1/241.1 kB 3.2 MB/s eta 0:00:00
# Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 37.4 MB/s eta 0:00:00
# Downloading rocketchat_API-1.28.1-py3-none-any.whl (20 kB)
# Downloading ruamel.yaml-0.17.40-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 7.5 MB/s eta 0:00:00
# Downloading sanic-21.12.2-py3-none-any.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 8.6 MB/s eta 0:00:00
# Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# Downloading sanic_jwt-1.8.0-py3-none-any.whl (23 kB)
# Downloading sanic_routing-0.7.2-py3-none-any.whl (23 kB)
# Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 24.6 MB/s eta 0:00:00
# Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 12.4 MB/s eta 0:00:00
# Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 11.1 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Downloading slack_sdk-3.34.0-py2.py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.5/292.5 kB 17.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.6 MB/s eta 0:00:00
# Downloading tarsafe-0.0.3-py3-none-any.whl (5.0 kB)
# Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 3.6 MB/s eta 0:00:00
# Downloading tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.2 MB/s eta 0:00:00
# Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 6.6 MB/s eta 0:00:00
# Downloading tensorflow_text-2.8.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 64.2 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Downloading twilio-7.14.2-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.8 MB/s eta 0:00:00
# Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.3 MB/s eta 0:00:00
# Downloading webexteamssdk-1.6.1-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 7.9 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiormq-6.6.4-py3-none-any.whl (30 kB)
# Downloading pamqp-3.2.1-py2.py3-none-any.whl (33 kB)
# Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 69.3 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading botocore-1.35.93-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 59.3 MB/s eta 0:00:00
# Downloading dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 12.1 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 21.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.7 MB/s eta 0:00:00
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.7 MB/s eta 0:00:00
# Downloading magic_filter-1.0.12-py3-none-any.whl (11 kB)
# Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 12.6 MB/s eta 0:00:00
# Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.8 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.9 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 36.6 MB/s eta 0:00:00
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 6.0 MB/s eta 0:00:00
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 93.6 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 26.6 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 68.4 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 85.1 MB/s eta 0:00:00
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 36.9 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: mattermostwrapper, pymongo, randomname, docopt, fire
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-py3-none-any.whl size=2447 sha256=57feee6eb29d23d2d68f3cddb3ab77a03f10879753a418860f9a4504ceca3699
#   Stored in directory: /root/.cache/pip/wheels/b2/dc/02/e3239f0ea0a676085826846d32ef09b10915c0a33c817d2dbb
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.10.1-cp310-cp310-linux_x86_64.whl size=462797 sha256=32b30a202836f5c0eafe9226b7161d25f11843f43dccd9e5294fa15417c00092
#   Stored in directory: /root/.cache/pip/wheels/29/ff/28/8624f4571ee5e095adb4057078b7bfc1d44d5d0a158d4f24bb
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.1.5-py3-none-any.whl size=58808 sha256=630871412e26a4ca986ed777865748a882452944660e2094a5501507bd270571
#   Stored in directory: /root/.cache/pip/wheels/ee/df/c1/0bdf17c694217f49657ca36fd0239b9a243c34c27a70ff56ef
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=273360eeb29b0ab094ad6f7eb154f39aebe5f92c4a9c7572772e1ac3c0b7abf7
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=4cdeb6f7a2ccf4b1fba6b04b83b512ab9763c02f7b02d24a6375629b7bd46d3f
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built mattermostwrapper pymongo randomname docopt fire
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, sanic-routing, pytz, keras, docopt, confluent-kafka, wsproto, uvloop, ujson, typing-utils, terminaltables, tensorboard-data-server, tarsafe, SQLAlchemy, slack-sdk, sentry-sdk, sanic-jwt, ruamel.yaml.clib, regex, redis, python-crfsuite, pyrsistent, pymongo, pydot, pydantic, psycopg2-binary, protobuf, prompt-toolkit, pamqp, packaging, numpy, networkx, multidict, magic-filter, jsonpickle, joblib, jmespath, humanfriendly, httptools, fire, dnspython, colorhash, colorclass, cloudpickle, bidict, Babel, attrs, apscheduler, aiofiles, absl-py, twilio, tensorflow_hub, tensorflow-addons, sklearn-crfsuite, simple-websocket, scipy, sanic, ruamel.yaml, rocketchat_API, randomname, questionary, mattermostwrapper, matplotlib, keras-preprocessing, jsonschema, fbmessenger, dask, coloredlogs, CacheControl, botocore, webexteamssdk, scikit-learn, sanic-cors, s3transfer, python-engineio, pykwalify, google-auth-oauthlib, aiormq, aiohttp, tensorboard, rasa-sdk, python-socketio, boto3, aiogram, aio-pika, tensorflow, tensorflow-text, rasa
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 2.19.2
#     Uninstalling sentry-sdk-2.19.2:
#       Successfully uninstalled sentry-sdk-2.19.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.3
#     Uninstalling pydot-3.0.3:
#       Successfully uninstalled pydot-3.0.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.48
#     Uninstalling prompt_toolkit-3.0.48:
#       Successfully uninstalled prompt_toolkit-3.0.48
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.1.0
#     Uninstalling multidict-6.1.0:
#       Successfully uninstalled multidict-6.1.0
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 4.0.1
#     Uninstalling jsonpickle-4.0.1:
#       Successfully uninstalled jsonpickle-4.0.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.0
#     Uninstalling cloudpickle-3.1.0:
#       Successfully uninstalled cloudpickle-3.1.0
#   Attempting uninstall: Babel
#     Found existing installation: babel 2.16.0
#     Uninstalling babel-2.16.0:
#       Successfully uninstalled babel-2.16.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 24.3.0
#     Uninstalling attrs-24.3.0:
#       Successfully uninstalled attrs-24.3.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.16.1
#     Uninstalling tensorflow-hub-0.16.1:
#       Successfully uninstalled tensorflow-hub-0.16.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2024.10.0
#     Uninstalling dask-2024.10.0:
#       Successfully uninstalled dask-2024.10.0
#   Attempting uninstall: CacheControl
#     Found existing installation: CacheControl 0.14.1
#     Uninstalling CacheControl-0.14.1:
#       Successfully uninstalled CacheControl-0.14.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.0
#     Uninstalling scikit-learn-1.6.0:
#       Successfully uninstalled scikit-learn-1.6.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.10
#     Uninstalling aiohttp-3.11.10:
#       Successfully uninstalled aiohttp-3.11.10
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.2 which is incompatible.
# albumentations 1.4.20 requires scipy>=1.10.0, but you have scipy 1.8.1 which is incompatible.
# arviz 0.20.0 requires scipy>=1.9.0, but you have scipy 1.8.1 which is incompatible.
# bigframes 1.29.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# bigframes 1.29.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.1.3 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# google-ai-generativelanguage 0.6.10 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-aiplatform 1.74.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-bigquery-connection 1.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-bigquery-storage 2.27.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-bigtable 2.27.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-datastore 2.20.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-firestore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-functions 1.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-iam 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-language 2.16.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-pubsub 2.27.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-resource-manager 1.14.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-translate 3.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-genai 0.3.0 requires pydantic<3.0.0dev,>=2.0.0, but you have pydantic 1.10.2 which is incompatible.
# googleapis-common-protos 1.66.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# grpc-google-iam-v1 0.13.1 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.19.6 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jax 0.4.33 requires scipy>=1.10, but you have scipy 1.8.1 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires scipy>=1.10, but you have scipy 1.8.1 which is incompatible.
# langchain 0.3.12 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.2 which is incompatible.
# langchain-core 0.3.25 requires packaging<25,>=23.2, but you have packaging 20.9 which is incompatible.
# langchain-core 0.3.25 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.2 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.1.3 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.6.3 which is incompatible.
# pandas-gbq 0.25.0 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# pandas-gbq 0.25.0 requires packaging>=22.0.0, but you have packaging 20.9 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.5.3 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# referencing 0.35.1 requires attrs>=22.2.0, but you have attrs 22.1.0 which is incompatible.
# scikit-image 0.25.0 requires networkx>=3.0, but you have networkx 2.6.3 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.25.0 requires packaging>=21, but you have packaging 20.9 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.8.1 which is incompatible.
# shap 0.46.0 requires packaging>20.9, but you have packaging 20.9 which is incompatible.
# sphinx 8.1.3 requires babel>=2.13, but you have babel 2.9.1 which is incompatible.
# sphinx 8.1.3 requires packaging>=23.0, but you have packaging 20.9 which is incompatible.
# statsmodels 0.14.4 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# tensorflow-datasets 4.9.7 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.8.4 which is incompatible.
# wandb 0.19.1 requires pydantic<3,>=2.6, but you have pydantic 1.10.2 which is incompatible.
# wandb 0.19.1 requires sentry-sdk>=2.0.0, but you have sentry-sdk 1.11.1 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.11.0 requires packaging>=23.2, but you have packaging 20.9 which is incompatible.
# xarray-einstats 0.8.0 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# Successfully installed Babel-2.9.1 CacheControl-0.12.14 SQLAlchemy-1.4.54 absl-py-1.3.0 aio-pika-8.3.0 aiofiles-24.1.0 aiogram-2.23.1 aiohttp-3.8.6 aiormq-6.6.4 apscheduler-3.9.1.post1 attrs-22.1.0 bidict-0.23.1 boto3-1.35.93 botocore-1.35.93 cloudpickle-2.2.1 colorclass-2.2.2 coloredlogs-15.0.1 colorhash-1.2.1 confluent-kafka-1.9.2 dask-2022.10.2 dnspython-1.16.0 docopt-0.6.2 fbmessenger-6.0.0 fire-0.7.0 google-auth-oauthlib-0.4.6 httptools-0.6.4 humanfriendly-10.0 jmespath-1.0.1 joblib-1.2.0 jsonpickle-2.2.0 jsonschema-4.16.0 keras-2.8.0 keras-preprocessing-1.1.2 magic-filter-1.0.12 matplotlib-3.5.3 mattermostwrapper-2.2 multidict-5.2.0 networkx-2.6.3 numpy-1.23.5 packaging-20.9 pamqp-3.2.1 prompt-toolkit-3.0.28 protobuf-3.19.6 psycopg2-binary-2.9.10 pydantic-1.10.2 pydot-1.4.2 pykwalify-1.8.0 pymongo-3.10.1 pyrsistent-0.20.0 python-crfsuite-0.9.11 python-engineio-4.11.2 python-socketio-5.12.1 pytz-2022.7.1 questionary-1.10.0 randomname-0.1.5 rasa-3.4.5 rasa-sdk-3.4.1 redis-4.6.0 regex-2022.10.31 rocketchat_API-1.28.1 ruamel.yaml-0.17.40 ruamel.yaml.clib-0.2.12 s3transfer-0.10.4 sanic-21.12.2 sanic-cors-2.0.1 sanic-jwt-1.8.0 sanic-routing-0.7.2 scikit-learn-1.1.3 scipy-1.8.1 sentry-sdk-1.11.1 simple-websocket-1.1.0 sklearn-crfsuite-0.3.6 slack-sdk-3.34.0 tarsafe-0.0.3 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.4 tensorflow-addons-0.17.1 tensorflow-estimator-2.8.0 tensorflow-text-2.8.2 tensorflow_hub-0.12.0 terminaltables-3.1.10 twilio-7.14.2 typing-utils-0.1.0 ujson-5.10.0 uvloop-0.21.0 webexteamssdk-1.6.1 wsproto-1.2.0

# %%
# !pip install -U ipython #it provides a rich architecture for interactive computing
# Out:
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-8.31.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython) (1.2.2)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.9.0)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython)
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (2.18.0)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-8.31.0-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 12.3 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.3 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 16.9 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 4.5 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, traitlets, prompt_toolkit, jedi, executing, asttokens, stack_data, ipython
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: prompt_toolkit
#     Found existing installation: prompt-toolkit 3.0.28
#     Uninstalling prompt-toolkit-3.0.28:
#       Successfully uninstalled prompt-toolkit-3.0.28
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.31.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# rasa 3.4.5 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.48 which is incompatible.
# rasa-sdk 3.4.1 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.48 which is incompatible.
# Successfully installed asttokens-3.0.0 executing-2.1.0 ipython-8.31.0 jedi-0.19.2 prompt_toolkit-3.0.48 pure-eval-0.2.3 stack_data-0.6.3 traitlets-5.14.3

# %% [markdown]
# **Arranging enviroment**

# %%
# !pip install websockets==10.4
# !pip install websocket-client  #it enhances our chatbot's real-time communication, providing users with instant updates and an interactive experience.
# Out:
# Collecting websockets==10.4
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: websockets
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.1
#     Uninstalling websockets-14.1:
#       Successfully uninstalled websockets-14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 0.3.0 requires pydantic<3.0.0dev,>=2.0.0, but you have pydantic 1.10.2 which is incompatible.
# google-genai 0.3.0 requires websockets<15.0dev,>=13.0, but you have websockets 10.4 which is incompatible.
# Successfully installed websockets-10.4
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (1.8.0)

# %%
# !python -m spacy download en_core_web_sm #spacy elevates our chatbot's natural language understanding, ensuring quick and precise responses
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 83.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (20.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/spacy/__main__.py", line 4, in <module>
#     setup_cli()
#   File "/usr/local/lib/python3.10/dist-packages/spacy/cli/_util.py", line 87, in setup_cli
#     command(prog_name=COMMAND)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 743, in main
#     return _main(
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 198, in _main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/typer/main.py", line 698, in wrapper
#     return callback(**use_params)
#   File "/usr/local/lib/python3.10/dist-packages/spacy/cli/download.py", line 44, in download_cli
#     download(model, direct, sdist, *ctx.args)
#   File "/usr/local/lib/python3.10/dist-packages/spacy/cli/download.py", line 95, in download
#     if is_in_jupyter():
#   File "/usr/local/lib/python3.10/dist-packages/spacy/util.py", line 1095, in is_in_jupyter
#     import google.colab
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/__init__.py", line 19, in <module>
#     from google.colab import _interactive_table_hint_button
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py", line 18, in <module>
#     from google.colab import data_table as _data_table
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/data_table.py", line 319, in <module>
#     class _JavascriptModuleFormatter(_IPython.core.formatters.BaseFormatter):
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/data_table.py", line 320, in _JavascriptModuleFormatter
#     format_type = _traitlets.Unicode(_JAVASCRIPT_MODULE_MIME_TYPE)
# AttributeError: module 'IPython.utils.traitlets' has no attribute 'Unicode'

# %%
import spacy #importing spacy and creating a nlp attribute
nlp = spacy.load("en_core_web_sm")

# %%
# !pip install nest_asyncio==1.3.3 #nest_asyncio optimizes our chatbot's asynchronous operations, enhancing efficiency and responsiveness
# Out:
# Collecting nest_asyncio==1.3.3
#   Downloading nest_asyncio-1.3.3-py3-none-any.whl.metadata (2.5 kB)
# Downloading nest_asyncio-1.3.3-py3-none-any.whl (4.7 kB)
# Installing collected packages: nest_asyncio
#   Attempting uninstall: nest_asyncio
#     Found existing installation: nest-asyncio 1.6.0
#     Uninstalling nest-asyncio-1.6.0:
#       Successfully uninstalled nest-asyncio-1.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclassic 1.1.0 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# notebook 6.5.5 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# Successfully installed nest_asyncio-1.3.3

# %%
# Import necessary libraries
import os
import rasa
import nest_asyncio

# Initialize the event loop
nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %%
# Initialize rasa
from rasa.cli.scaffold import create_initial_project

# %%
project = "Air Ticket Counter Check Point"
create_initial_project(project)

# %%
# Construct the project path
os.chdir(project)
print(os.listdir("."))
# Out:
# ['endpoints.yml', 'credentials.yml', 'actions', 'domain.yml', 'config.yml', 'data', 'tests']

# %%
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %%
#Train the agent with the training data
model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/engine/caching.py:152: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# (0x(B for all its users.                                                             (0x(B
# (0x(B                                                                                (0x(B
# (0x(B If you'd like to opt-out, you can use `rasa telemetry disable`.                (0x(B
# (0x(B To learn more, check out https://rasa.com/docs/rasa/telemetry/telemetry.       (0x(B
# (0mqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqj(B
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# The configuration for pipeline and policies was chosen automatically. It was written into the config file at 'config.yml'.
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data_utils.py:400: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([v[0] for v in values]), number_of_dimensions=3
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data.py:774: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.concatenate(np.array(f)),
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Cast:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Epochs: 100%|██████████| 100/100 [02:06<00:00,  1.26s/it, t_loss=2.16, i_acc=1, e_f1=1]
# Processed story blocks: 100%|██████████| 21/21 [00:00<00:00, 325.97it/s, # trackers=1]
# Processed story blocks: 100%|██████████| 21/21 [00:00<00:00, 83.77it/s, # trackers=21]
# Processed story blocks: 100%|██████████| 21/21 [00:01<00:00, 15.07it/s, # trackers=50]
# Processed story blocks: 100%|██████████| 21/21 [00:00<00:00, 37.28it/s, # trackers=50]
# Processed rules: 100%|██████████| 2/2 [00:00<00:00, 249.13it/s, # trackers=1]
# Processed trackers: 100%|██████████| 21/21 [00:00<00:00, 258.26it/s, # action=62]
# Processed actions: 62it [00:00, 861.60it/s, # examples=62]
# Processed trackers: 100%|██████████| 2/2 [00:00<00:00, 171.48it/s, # action=5]
# Processed actions: 5it [00:00, 451.18it/s, # examples=4]
# Processed trackers: 100%|██████████| 21/21 [00:00<00:00, 249.62it/s, # action=62]
# Processed trackers: 100%|██████████| 2/2 [00:00<00:00, 930.93it/s]
# Processed trackers: 100%|██████████| 23/23 [00:00<00:00, 260.97it/s]
# Processed trackers: 100%|██████████| 521/521 [00:02<00:00, 233.73it/s, # action=652]
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data_utils.py:388: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(values), number_of_dimensions=4
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data_utils.py:404: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   MASK: [FeatureArray(np.array(attribute_masks), number_of_dimensions=3)]
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_1_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_1_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_1_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Epochs: 100%|██████████| 100/100 [01:13<00:00,  1.36it/s, t_loss=2.17, loss=1.92, acc=0.992]
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Processed trackers: 100%|██████████| 521/521 [00:01<00:00, 328.01it/s, # intent=192]
# Epochs: 100%|██████████| 100/100 [00:37<00:00,  2.68it/s, t_loss=0.224, loss=0.131, acc=0.938]
# /usr/local/lib/python3.10/dist-packages/rasa/core/policies/unexpected_intent_policy.py:839: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   quantile_values = np.quantile(  # type: ignore[call-overload]
# Your Rasa model is trained and saved at 'models/20250107-171758-chief-wave.tar.gz'.
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# TrainingResult(model='models/20250107-171758-chief-wave.tar.gz', code=0, dry_run_results=None)

# %% [markdown]
# **Training Data**

# %%
# %%writefile data/config.yml
#
# version: "3.1"
#
# language: "en"
#
# pipeline:
#   - name: WhitespaceTokenizer
#   - name: RegexFeaturizer
#   - name: LexicalSyntacticFeaturizer
#   - name: CountVectorsFeaturizer
#   - name: CountVectorsFeaturizer
#     analyzer: "char_wb"
#     min_ngram: 1
#     max_ngram: 4
#   - name: DIETClassifier
#     epochs: 100
#   - name: EntitySynonymMapper
#   - name: ResponseSelector
#     epochs: 100
#
# policies:
#   - name: MemoizationPolicy
#   - name: TEDPolicy
#   # - name: UnexpecTEDIntentPolicy
#   - name: RulePolicy
# Out:
# Writing data/config.yml

# %%
# %%writefile data/stories.yml
#
# version: "3.1"
#
# stories:
#
# - story: check in
#   steps:
#     - intent: greet
#     - action: utter_greet
#     - intent: check_in
#     - action: utter_check_in
#
#
# - story: Luggage limit
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: luggage_limit
#   - action: utter_luggage_limit
#
# - story: cancel flight
#   steps:
#     - intent: greet
#     - action: utter_greet
#     - intent: cancel_flight
#     - action: utter_cancel_flight
#
# - story: policy
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: can_policy
#   - action: utter_can_policy
#
# - story: Take off time US
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: take_of_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_us
#   - action: utter_take_of_time_US
#
# - story: Take off time Canada
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: take_of_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_canada
#   - action: utter_take_of_time_canada
#
# - story: Landing time Us
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: landing_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_us
#   - action: utter_landing_time_us
#
# - story: Landing time Canada
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: landing_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_canada
#   - action: utter_landing_time_canada
#
# - story: Travel time Us
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: travel_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_us
#   - action: utter_travel_time_us
#
# - story: Travel time Canada
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: travel_time
#   - action: utter_destination_conformation
#   - intent: destination_conformation_canada
#   - action: utter_travel_time_canada
#
# - story: Seat booking economy
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: seat_booking
#   - action: utter_seat_booking_class
#   - intent: needed_economy
#   - action: utter_seat_availability_economy
#   - intent: num_seat
#   - action: utter_seat_economy
#
# - story: Seat booking business
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: seat_booking
#   - action: utter_seat_booking_class
#   - intent: needed_business
#   - action: utter_seat_availability_business
#   - intent: num_seat
#   - action: utter_seat_business
#
# - story: Departure gate canada
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: departure_gate
#   - action: utter_destination_conformation
#   - intent: destination_conformation_canada
#   - action: utter_departure_gate_canada
#
# - story: Departure gate us
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: departure_gate
#   - action: utter_destination_conformation
#   - intent: destination_conformation_us
#   - action: utter_departure_gate_us
#
# - story: upgrade_to_business_class
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: upgrade_to_business_class
#   - action: utter_upgrade_to_business_class
#
# - story: restricted items
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: restricted_items
#   - action: utter_restricted_items
#
# - story: happy path
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_great
#   - action: utter_happy
#
# - story: sad path 1
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_unhappy
#   - action: utter_cheer_up
#   - action: utter_did_that_help
#   - intent: affirm
#   - action: utter_happy
#
# - story: sad goodbye
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_unhappy
#   - action: utter_cheer_up
#   - action: utter_did_that_help
#   - intent: deny
#   - action: utter_sad_goodbye
#
# - story: say goodbye
#   steps:
#   - intent: goodbye
#   - action: utter_goodbye
#
# - story: bot challenge
#   steps:
#   - intent: bot_challenge
#   - action: utter_iamabot
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/nlu.yml
#
# version: "3.1"
#
# nlu:
# - intent: check_in
#   examples: |
#     - I need to check in for my flight.
#     - Can I check in online?
#     - How do I go about checking in for my flight?
#     - Is online check-in available?
#     - I want to check in before my flight.
#     - What's the process for checking in?
#     - Do I need to check in at the airport?
#     - Can you help me with the check-in procedure?
#     - I'd like to check in online, please.
#
# - intent: luggage_limit
#   examples: |
#     - What is the luggage limit for this flight?
#     - What is the maximum weight of laggage I can carry?
#     - Is there a luggage limit for this flight?
#     - Can I carry 15kg of luggage for my travel?
#
# - intent: cancel_flight
#   examples: |
#     - How do I cancel my flight?
#     - Procedure of cancel a flight?
#     - Please cancel my flight.
#     - Can You please cancel my flight?
#
# - intent: can_policy
#   examples: |
#     - What is your cancellation policy?
#     - can you tell me about the cancellation policy of your flight?
#     - cancellation policy of your flight?
#     - Is there any cancellation plicy of your flight?
#     - cancellation Policy of your flight?
#
# - intent: take_of_time
#   examples: |
#     - At what time is the flight taking off?
#     - Is there a specific time for take off?
#     - When should I be at the boarding area?
#     - When is the take of time?
#
# - intent: destination_conformation_us
#   examples: |
#     - US
#     - United States
#     - Yes, my destination is the United States.
#     - That's correct, I'm heading to the US.
#     - Confirming, my flight is to the United States.
#     - Yes, I'm flying to the US.
#     - Affirmative, my final destination is in the United States.
#     - That's right, I'm going to the United States.
#     - Yes, the US is my destination.
#     - Confirming, I'll be arriving in the United States.
#
# - intent: destination_conformation_canada
#   examples: |
#     - Canada
#     - Yes, my destination is Canada.
#     - That's correct, I'm heading to Canada.
#     - Confirming, my flight is to Canada.
#     - Yes, I'm flying to Canada.
#     - Affirmative, my final destination is in Canada.
#     - That's right, I'm going to Canada.
#     - Yes, Canada is my destination.
#     - Confirming, I'll be arriving in Canada.
#
# - intent: landing_time
#   examples: |
#     - When will I land in my destination?
#     - At what time am I suppose to land?
#     - When will the flight end?
#     - When can I get off the flight?
#     - At what time does the flight end?
#
# - intent: travel_time
#   examples: |
#     - How long is the flight?
#     - can you tell me how long will i be in the flight?
#     - is this the longest flight?
#     - what is travel time
#     - how long does the flight takes?
#
# - intent: seat_booking
#   examples: |
#     - i want to book a seat on the flight?
#     - i need a seat for the flight?
#     - can i book a windown seat?
#     - i am trying to reserve a seat
#     - what are the seat option for this flight?
#
# - intent: needed_economy
#   examples: |
#     - I want to book a seat in economy class.
#     - Can you help me with booking an economy class seat?
#     - I prefer economy class for my flight.
#     - I need to reserve a seat in the economy section.
#     - Please book me a seat in the economy class.
#     - I'm looking to fly in the economy class.
#     - How can I book a seat in economy?
#
# - intent: needed_business
#   examples: |
#     - I would like to book a seat in the business class.
#     - Can you help me with reserving a business class seat?
#     - I prefer the business class for my flight.
#     - I need to book a seat in the business section.
#     - Please reserve a seat for me in the business class.
#     - I'm looking to fly in the business class.
#     - How can I book a seat in the business class?
#     - Business class booking, please.
#
# - intent: num_seat
#   examples: |
#     - i want to [2](number) seat
#     - is [3](number) seat available
#     - can i get the [9](number) seat
#     - [7](number) seat
#
# - intent: departure_gate
#   examples: |
#     - where is my departure gate
#     - where should i be to get on the flight
#     - from which gate does my flight departures
#     - departure gate
#
# - intent: upgrade_to_business_class
#   examples: |
#     - can i upgrade my flight to business class
#     - how can i upgrade my flight
#     - i want to travel in business class
#     - business class deals
#     - upgrade from economy to business
#
# - intent: restricted_items
#   examples: |
#     - can i bring a knife on the flight?
#     - what items are strictly not allowed
#     - is it possible to bring liquid substance
#     - what are prohibited from the flight
#     - restricted items
#
# - intent: greet
#   examples: |
#     - hey
#     - hello
#     - hi
#     - good morning
#     - good evening
#     - hey there
#
# - intent: goodbye
#   examples: |
#     - bye
#     - goodbye
#     - see you around
#     - see you later
#
# - intent: affirm
#   examples: |
#     - yes
#     - indeed
#     - of course
#     - that sounds good
#     - correct
#
# - intent: deny
#   examples: |
#     - no
#     - never
#     - I don't think so
#     - don't like that
#     - no way
#     - not really
#
# - intent: mood_great
#   examples: |
#     - perfect
#     - very good
#     - great
#     - amazing
#     - wonderful
#     - I am feeling very good
#     - I am great
#     - I'm good
#
# - intent: mood_unhappy
#   examples: |
#     - sad
#     - very sad
#     - unhappy
#     - bad
#     - very bad
#     - awful
#     - terrible
#     - not very good
#     - extremely sad
#     - so sad
#
# - intent: bot_challenge
#   examples: |
#     - are you a bot?
#     - are you a human?
#     - am I talking to a bot?
#     - am I talking to a human?
# Out:
# Overwriting data/nlu.yml

# %%
# %%writefile domain.yml
#
# version: "3.1"
#
#
#
# intents:
#   - check_in
#   - luggage_limit
#   - cancel_flight
#   - can_policy
#   - take_of_time
#   - destination_conformation_us
#   - destination_conformation_canada
#   - landing_time
#   - seat_booking
#   - needed_economy
#   - needed_business
#   - travel_time
#   - restricted_items
#   - num_seat
#   - departure_gate
#   - upgrade_to_business_class
#   - greet
#   - goodbye
#   - affirm
#   - deny
#   - mood_great
#   - mood_unhappy
#   - bot_challenge
#
# responses:
#
#   utter_check_in:
#   - text: "Please wait until our agent connect with you"
#
#   utter_luggage_limit:
#   - text: '''You can check in as many bags as you like up to the weight allowance for your travel class. Each individual bag must not weigh more than 32kg (for mor details please log in to our website)'''
#
#   utter_can_policy:
#   - text: "Please log in to our website to get full details about our policy"
#
#   utter_cancel_flight:
#   - text: "Your ticket cancelation request sent successfully, Please wait until our agent connect with you"
#
#   utter_destination_conformation:
#   - text: "Please confirm your destination. Is it to Us or Canada?"
#
#   utter_take_of_time_US:
#   - text: "Every day our flight to US take of at 9:00 am "
#
#   utter_take_of_time_canada:
#   - text: "Every day our flight to US take of at 4:00 pm"
#
#   utter_landing_time_canada:
#   - text: "Every day our flight to US land in New York International Airport at 11:00am (in local time)"
#
#   utter_landing_time_us:
#   - text: "Every day our flight to canada lands in Halifax Stanfield International Airport at 06:00pm (in local time)"
#
#   utter_travel_time_canada:
#   - text: "Travel time from London to New York International Airport is 3 hours"
#
#   utter_travel_time_us:
#   - text: "Travel time from London to Halifax Stanfield International Airpor is 3 hours"
#
#   utter_seat_booking_class:
#   - text: "Which class do you prefer Economy or Business"
#
#   utter_seat_availability_economy:
#   - text: "We have only few seats remaining in economy class please book your seat as soon as possible"
#
#   utter_seat_economy:
#   - text: "Your economy class seat booking conformation is successfully submited, Please wait until our agent connects with you"
#
#   utter_seat_availability_business:
#   - text: "We have only few seats remaining in business class please book your seat as soon as possible"
#
#   utter_seat_business:
#   - text: "Your business class seat booking conformation is successfully submited, Please wait until our agent connects with you"
#
#   utter_departure_gate_canada:
#   - text: "Departure gate for passengers who are traveling to Canada is gate No.C5"
#
#   utter_departure_gate_us:
#   - text: "Departure gate for passengers who are traveling to US is gate No.A12"
#
#   utter_restricted_items:
#   - text: "Restricted items on flights typically include sharp objects like knives, firearms, and explosives, as well as flammable materials, corrosive substances, and certain liquids exceeding the 3-1-1 rule. Sporting equipment such as baseball bats or golf clubs may also be restricted for safety reasons. Passengers should check airline and aviation authority guidelines to ensure compliance with regulations."
#
#   utter_upgrade_to_business_class:
#   - text: "Please wait until our agent connect with you"
#
#   utter_greet:
#   - text: "Hey! Welcome to our Air line,I'm AirlineGPT, How may i help you?"
#
#   utter_cheer_up:
#   - text: "Here is something to cheer you up:"
#     image: "https://i.imgur.com/nGF1K8f.jpg"
#
#   utter_did_that_help:
#   - text: "Did that help you?"
#
#   utter_happy:
#   - text: "Great, carry on!"
#
#   utter_goodbye:
#   - text: "Bye"
#
#   utter_sad_goodbye:
#   - text: "Bye"
#
#   utter_iamabot:
#   - text: "I am AirlineGPT, powered by Rasa."
#
# entities:
#   - number
#
#
# session_config:
#   session_expiration_time: 60
#   carry_over_slots_to_new_session: true
# Out:
# Overwriting domain.yml

# %%
from rasa.jupyter import chat

#endpoints = 'endpoints.yml'

endpoints = None

# %% [markdown]
# **Testing**

# %% [markdown]
# **Flight information**

# %%
# Start the conversation
chat(model_path.model, endpoints)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Cast:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_1_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_1_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_1_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hi
# Hey! Welcome to our Air line,I'm AirlineGPT, How may i help you?
# /stop

# %% [markdown]
# **Booking the flight**

# %%
chat(model_path.model, endpoints)
# Out:
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hi
# Hey! Welcome to our Air line,I'm AirlineGPT, How may i help you?
# i am trying to reserve a seat
# Which class do you prefer Economy or Business
# i want to book business class
# We have only few seats remaining in business class please book your seat as soon as possible
# i want 2 seats
# Your business class seat booking conformation is successfully submited, Please wait until our agent connects with you
# /stop

# %% [markdown]
# **Restricted items in flight**

# %%
chat(model_path.model, endpoints)
# Out:
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hello
# Hey! Welcome to our Air line,I'm AirlineGPT, How may i help you?
# what items are strictly not allowed
# Restricted items on flights typically include sharp objects like knives, firearms, and explosives, as well as flammable materials, corrosive substances, and certain liquids exceeding the 3-1-1 rule. Sporting equipment such as baseball bats or golf clubs may also be restricted for safety reasons. Passengers should check airline and aviation authority guidelines to ensure compliance with regulations.
# /stop

# %% [markdown]
# **Where is the departure gate**

# %%
chat(model_path.model, endpoints)
# Out:
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# hello
# Hey! Welcome to our Air line,I'm AirlineGPT, How may i help you?
# where is my departure gate
# Please confirm your destination. Is it to Us or Canada?
# US
# Departure gate for passengers who are traveling to US is gate No.A12
# /stop

# %% [markdown]
# **Test completed**

# %%
import rasa.shared.data as data
nlu_data_directory = data.get_nlu_directory(training_files)
stories_directory = data.get_core_directory(training_files)
print(stories_directory, nlu_data_directory)
rasa.test(model_path, stories_directory, nlu_data_directory)
print("Done testing.")
# Out:
# /tmp/tmpbh_j5czt /tmp/tmp9uf888s8
# Done testing.
# /usr/local/lib/python3.10/dist-packages/rasa/api.py:143: RuntimeWarning: coroutine 'test_core' was never awaited
#   test_core(model, stories, output, additional_arguments)  # type: ignore[unused-coroutine] # noqa: E501
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.10/dist-packages/rasa/api.py:144: RuntimeWarning: coroutine 'test_nlu' was never awaited
#   test_nlu(model, nlu_data, output, additional_arguments)  # type: ignore[unused-coroutine] # noqa: E501
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# **Facial recognition system**

# %% [markdown]
# **Deep face**

# %%
# !pip install dlib
# !pip install deepface
# Out:
# Requirement already satisfied: dlib in /usr/local/lib/python3.10/dist-packages (19.24.2)
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (1.23.5)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (11.0.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.8.4)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (2.8.0)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from deepface) (3.1.0)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: fire>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from deepface) (0.7.0)
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->deepface) (3.16.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gunicorn>=20.1.0->deepface) (20.9)
# Collecting joblib>=1.4.2 (from mtcnn>=0.1.0->deepface)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->deepface) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->deepface) (2024.12.14)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (2.8.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->deepface) (1.68.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging->gunicorn>=20.1.0->deepface) (3.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.2.2)
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.0 MB/s eta 0:00:00
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.0 MB/s eta 0:00:00
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 47.1 MB/s eta 0:00:00
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 27.3 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.4 MB/s eta 0:00:00
# Installing collected packages: lz4, joblib, mtcnn, gunicorn, flask-cors, retina-face, deepface
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.1.3 which is incompatible.
# rasa 3.4.5 requires joblib<1.3.0,>=0.15.1, but you have joblib 1.4.2 which is incompatible.
# rasa 3.4.5 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.48 which is incompatible.
# shap 0.46.0 requires packaging>20.9, but you have packaging 20.9 which is incompatible.
# Successfully installed deepface-0.0.93 flask-cors-5.0.0 gunicorn-23.0.0 joblib-1.4.2 lz4-4.3.3 mtcnn-1.0.0 retina-face-0.0.17

# %%
import cv2
import os
import dlib
from deepface import DeepFace
# Out:
# 25-01-07 14:17:22 - Directory /root/.deepface has been created
# 25-01-07 14:17:22 - Directory /root/.deepface/weights has been created

# %% [markdown]
# **Call to Data set**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install rasa-sdk
# Out:
# Requirement already satisfied: rasa-sdk in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: Sanic-Cors<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa-sdk) (2.0.1)
# Requirement already satisfied: coloredlogs<16,>=10 in /usr/local/lib/python3.10/dist-packages (from rasa-sdk) (15.0.1)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa-sdk)
#   Using cached prompt_toolkit-3.0.28-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.16.5 in /usr/local/lib/python3.10/dist-packages (from rasa-sdk) (0.17.40)
# Requirement already satisfied: sanic<22.0.0,>=21.12.0 in /usr/local/lib/python3.10/dist-packages (from rasa-sdk) (21.12.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from rasa-sdk) (4.12.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs<16,>=10->rasa-sdk) (10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa-sdk) (0.2.13)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml<0.18.0,>=0.16.5->rasa-sdk) (0.2.12)
# Requirement already satisfied: sanic-routing~=0.7 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (0.7.2)
# Requirement already satisfied: httptools>=0.0.10 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (0.6.4)
# Requirement already satisfied: aiofiles>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (24.1.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (10.4)
# Requirement already satisfied: multidict<6.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (5.2.0)
# Requirement already satisfied: uvloop>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (0.21.0)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.10/dist-packages (from sanic<22.0.0,>=21.12.0->rasa-sdk) (5.10.0)
# Using cached prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
# Installing collected packages: prompt-toolkit
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.48
#     Uninstalling prompt_toolkit-3.0.48:
#       Successfully uninstalled prompt_toolkit-3.0.48
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.31.0 requires prompt_toolkit<3.1.0,>=3.0.41, but you have prompt-toolkit 3.0.28 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# rasa 3.4.5 requires joblib<1.3.0,>=0.15.1, but you have joblib 1.4.2 which is incompatible.
# Successfully installed prompt-toolkit-3.0.28

# %%
# actions.py

from rasa_sdk import Action, Tracker
from rasa_sdk.executor import CollectingDispatcher
from deepface import DeepFace

class VerifyThePassengerAction(Action):
    def name(self):
        return "verify_the_passenger"

    async def run(self, dispatcher: CollectingDispatcher, tracker: Tracker, domain: dict) -> list:

        passport_number = tracker.get_slot("passport_number")
        booking_reference = tracker.get_slot("booking_reference")

        verification_result = self.face_recognition_verification(passport_number)

        if verification_result:
            dispatcher.utter_message("Face recognition successful. How can I assist you with your check-in?")
        else:
            dispatcher.utter_message("Face recognition failed. Please check your face and try again.")

        return []

    def face_recognition_verification(self, passport_number):

        img1_path = f"/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/PP image/{passport_number}"
        img2_path = f"/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/Current image/{passport_number}"

        result = DeepFace.verify(img1_path=img1_path, img2_path=img2_path)
        face_verification_result = result['verified']

        return face_verification_result

# %%
from google.colab.patches import cv2_imshow # for image display

# %% [markdown]
# **Varification with passport image**

# %%
passport_number = input("Enter passenger's Passport Number :-")
image = (f"/{passport_number}.jpg")
result1 = DeepFace.verify(img1_path = "/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/Current image"+image, img2_path = "/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/PP image"+image)

face_verification_result = result1['verified']

if face_verification_result is True:
  print("Face recognition test passed")
else:
  print("Face recognition test failed")
# Out:
# Enter passenger's Passport Number :-22334455
# Face recognition test passed

# %% [markdown]
# **Detect domain image for security purrpose**

# %%
from google.colab.patches import cv2_imshow
from deepface import DeepFace
import cv2

result2 = DeepFace.analyze("/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/Current image"+image)
first_result = result2[0]
face_emotion_result = first_result['dominant_emotion']

print(f"domain emotion is {face_emotion_result}")

name = "/Ticket No.01 C.jpg"
frame = cv2.imread("/content/gdrive/MyDrive/Colab Notebooks/Project 2 AIDD/Current image"+image)

try:
    res = DeepFace.analyze(frame, actions=['emotion'])
    print(res[0]['dominant_emotion'])
    print(res)  # Print the entire result to examine its structure

    # Draw rectangles around faces
    x = int(res[0]['region']['x'])
    y = int(res[0]['region']['y'])
    w = int(res[0]['region']['w'] + x)
    h = int(res[0]['region']['h'] + y)
    cv2.rectangle(frame, (x, y), (w, h), (0, 255, 0), 2)

    text = res[0]['dominant_emotion']
    startY = y
    startX = x
    y = startY - 10 if startY - 10 > 10 else startY + 10
    cv2.putText(frame, text, (startX, y),
                cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)

    cv2_imshow(frame)

except Exception as e:
    print(e)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
